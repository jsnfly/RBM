# %%
import tensorflow as tf
import numpy as np
import pickle
import os
import matplotlib.pyplot as plt
import sys
sys.path.append('../')
from evaluate.helper_functions import *

# restrict tensorflow to only one GPU
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# /home/jonas/anaconda3/envs/TF19/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
def load_mnist_data():
    """
    Download mnist data if it does not already exist in directory mnist_data, else load it from directory.
    """
    try:
        x_train = np.load('mnist_data/train_data.npy')
        y_train = np.load('mnist_data/train_labels.npy')
        x_test = np.load('mnist_data/test_data.npy')
        y_test = np.load('mnist_data/test_labels.npy')

        print('mnist/data already exists, loaded files.')

    except IOError:
        if not os.path.exists('mnist_data'):
            os.makedirs('mnist_data')
        print('Downloading mnist data.')
        (x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data(path='mnist.npz')

        print('saving mnist data in mnist_data/')
        np.save('mnist_data/train_data', x_train)
        np.save('mnist_data/train_labels', y_train)
        np.save('mnist_data/test_data', x_test)
        np.save('mnist_data/test_labels', y_test)

    # Reshape data into shape [num_samples,num_features]
    x_train = x_train.reshape((x_train.shape[0], -1))
    x_test = x_test.reshape((x_test.shape[0], -1))

    print('shape training examples: ', x_train.shape)
    print('shape training labels: ', y_train.shape)
    print('shape test examples: ', x_test.shape)
    print('shape test labels: ', y_test.shape)

    return (x_train, y_train), (x_test, y_test)


def threshold_data(data, threshold):
    """
    threshold data with threshold value
    :param data: numpy array
    :param threshold: float
    :return: thresholded data
    """
    data = np.where(data >= threshold, np.ones_like(data), np.zeros_like(data))
    data = data.astype(np.float32)
    return data

# %%
# load data
(x_train, y_train), (x_test, y_test) = load_mnist_data()
# Out:
# mnist/data already exists, loaded files.
# shape training examples:  (60000, 784)
# shape training labels:  (60000,)
# shape test examples:  (10000, 784)
# shape test labels:  (10000,)

# %%
# threshold data
x_train = threshold_data(x_train, 0.5 * 255)
x_test = threshold_data(x_test, 0.5*255)

# %%
# plot one random image to check if the format is correct
plt.imshow(x_train[np.random.randint(x_train.shape[0]), :].reshape([28, 28]), cmap='binary')
plt.colorbar()
plt.show()

# %%
# set up Deep Belief Network
layer_sizes = [784, 256, 256]
layer_types = ['bb', 'bb']
mnist_dbn = generate_dbn(layer_sizes, layer_types)

# %%
# training parameters
dbn_train_params = {
    'epochs': [32, 32],  # number of training epochs
    'batch_size': [128, 128],  # size of one training batch
    'cd_steps': [1, 1],  # number of CD training steps
    'update_vbiases': [True, True],  # if false vbiases are set to zero throughout the training
    'learning_rate': [0.3, 0.3],  # learning rate at the begin of training
    'lr_decay': [(5, 0.5), (5, 0.5)],  # decay of learning rate (every epochs,decay factor)
    'summary_frequency': [250, 250],  # write to summary every x batches
    'sparsity_rate': [0.0, 0.0],  # rate with which sparsity is enforced
    'sparsity_goal': [0.0, 0.0]  # goal activation probability
}

# %%
# Train DBN
summaries_path = 'mnist_test1/'

for li in range(len(mnist_dbn)):
    # set up layer summary path
    summary_path = summaries_path + 'layer{}'.format(li)

    # get training parameters for each layer from DBN_train_params
    layer = mnist_dbn[li]
    epochs = extract_value(dbn_train_params, 'epochs', li, 10)
    batch_size = extract_value(dbn_train_params, 'batch_size', li, 32)
    cd_steps = extract_value(dbn_train_params, 'cd_steps', li, 1)
    update_vbiases = extract_value(dbn_train_params, 'update_vbiases', li, False)
    start_learning_rate = extract_value(dbn_train_params, 'learning_rate', li, 0.1)
    lr_decay = extract_value(dbn_train_params, 'lr_decay', li, (10, 0.9))
    summary_frequency = extract_value(dbn_train_params, 'summary_frequency', li, 10)
    sparsity_rate = extract_value(dbn_train_params, 'sparsity_rate', li, 0)
    sparsity_goal = extract_value(dbn_train_params, 'sparsity_goal', li, 0)

    layer.train_rbm(train_data=x_train,
                    epochs=epochs,
                    batch_size=batch_size,
                    summary_path=summary_path,
                    summary_frequency=summary_frequency,
                    dbn=mnist_dbn,
                    update_vbiases=update_vbiases,
                    start_learning_rate=start_learning_rate,
                    learning_rate_decay=lr_decay,
                    cd_steps=cd_steps,
                    sparsity_rate=sparsity_rate,
                    sparsity_goal=sparsity_goal)

    # save trained dbn:
    pickle_out = open(summaries_path + 'dbn.pickle', 'wb')
    pickle.dump(mnist_dbn, pickle_out)
    pickle_out.close()

    # save parameter dicts:
    pickle_out = open(summaries_path + 'dbn_train_params.pickle', 'wb')
    pickle.dump(dbn_train_params, pickle_out)
    pickle_out.close()
# Out:
# WARNING:tensorflow:From ../train/rbm.py:129: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Starting training...
# Epoch 0/32
# Epoch 1/32
# Epoch 2/32
# Epoch 3/32
# Epoch 4/32
# Epoch 5/32
# Epoch 6/32
# Epoch 7/32
# Epoch 8/32
# Epoch 9/32
# Epoch 10/32
# Epoch 11/32
# Epoch 12/32
# Epoch 13/32
# Epoch 14/32
# Epoch 15/32
# Epoch 16/32
# Epoch 17/32
# Epoch 18/32
# Epoch 19/32
# Epoch 20/32
# Epoch 21/32
# Epoch 22/32
# Epoch 23/32
# Epoch 24/32
# Epoch 25/32
# Epoch 26/32
# Epoch 27/32
# Epoch 28/32
# Epoch 29/32
# Epoch 30/32
# Epoch 31/32
# Starting training...
# Epoch 0/32
# Epoch 1/32
# Epoch 2/32
# Epoch 3/32
# Epoch 4/32
# Epoch 5/32
# Epoch 6/32
# Epoch 7/32
# Epoch 8/32
# Epoch 9/32
# Epoch 10/32
# Epoch 11/32
# Epoch 12/32
# Epoch 13/32
# Epoch 14/32
# Epoch 15/32
# Epoch 16/32
# Epoch 17/32
# Epoch 18/32
# Epoch 19/32
# Epoch 20/32
# Epoch 21/32
# Epoch 22/32
# Epoch 23/32
# Epoch 24/32
# Epoch 25/32
# Epoch 26/32
# Epoch 27/32
# Epoch 28/32
# Epoch 29/32
# Epoch 30/32
# Epoch 31/32

# %%
# load DBN
dbn_path = 'mnist_test1/'
dbn_path = os.fspath(os.path.join(dbn_path, 'dbn.pickle'))
dbn = load_dbn(dbn_path)

# %%
# plot features
save_path = 'mnist_test1/features/'
if not os.path.exists(save_path):
    os.makedirs(save_path)
    
for layer_index in range(len(dbn)):
    layer = dbn[layer_index]
    inds = np.random.choice(range(layer.num_hunits), size=16, replace=False)

    # plot features with downward propagation
    receptive_fields = downward_propagate_features(dbn, layer_index, inds,
                                                   num_runs=200,
                                                   num_neurons=10,
                                                   activation_value=1.0)
    fig, axes = plt.subplots(4, 4, figsize=(2.895, 2.895))
    for c, ax in enumerate(axes.flat):
        receptive_field = receptive_fields[c]
        ax.imshow(receptive_field.reshape([28, 28]), cmap='seismic')
        ax.set_xticks([])
        ax.set_yticks([])
    plt.subplots_adjust(wspace=0.05, hspace=0.05)
    if save_path is not None:
        plt.savefig(save_path + 'receptive_fields_layer{}.png'.format(layer_index), format='png')
    plt.show()

# %%
import evaluate.dimensionless_disrcrimination_value as ddv
from evaluate.plot import *

# %%
# plot pca and tsne and calculate discrimination value
save_path = 'mnist_test1/pca_and_tsne/'
if not os.path.exists(save_path):
    os.makedirs(save_path)
    
# make samples indices
np.random.seed(420)
test_indices = make_sample_indices(x_test, 400)

test_samples = x_test[test_indices]
test_labels = y_test[test_indices]

# make pca and tsne of the input layer
pca_samples = calculate_pca(test_samples)
tsne_samples = calculate_tsne(test_samples)

# save plots of pca and tsne of the input layer
pca_plot = plot_pca_or_tsne(pca_samples, test_labels, one_hot_labels=False)
plt.savefig(save_path + 'pca_input_layer.png', format='png')
plt.show()

tsne_plot = plot_pca_or_tsne(tsne_samples, test_labels, one_hot_labels=False)
plt.savefig(save_path + 'tsne_input_layer.png', format='png')
plt.show()

# calculate discrimination value
discrimination_values = []
discrimination_value = ddv.discrimination_value(test_samples,
                                                test_labels,
                                                norm='z')
discrimination_values.append(discrimination_value)

# calculate layerwies activations
layer_activations = layerwise_activations(dbn, test_samples, num_activations=100)

# make and plot pca and tsne for higher layers, calculate discrimination value
for layer_index in range(len(dbn)):
    pca_samples = calculate_pca(layer_activations[layer_index])
    tsne_samples = calculate_tsne(layer_activations[layer_index])

    pca_plot = plot_pca_or_tsne(pca_samples, test_labels, one_hot_labels=False)
    plt.savefig(save_path + 'pca_layer{}.png'.format(layer_index), format='png')
    plt.show()

    tsne_plot = plot_pca_or_tsne(tsne_samples, test_labels, one_hot_labels=False)
    plt.savefig(save_path + 'tsne_layer{}.png'.format(layer_index), format='png')
    plt.show()

    discrimination_value = ddv.discrimination_value(layer_activations[layer_index],
                                                    test_labels,
                                                    norm='z')
    discrimination_values.append(discrimination_value)

plt.plot(discrimination_values)
plt.savefig(save_path + 'discrimination_values.png', format='png')
plt.show()
# Out:
# num zero dimensions:  242
# intra_sum 295.61390048869265 extra_sum 1461.767080509992 discrimination_value -1.2552451464852012
# num zero dimensions:  0
# intra_sum 200.1295851808175 extra_sum 1022.0138377395967 discrimination_value -1.6865375614710825
# num zero dimensions:  0
# intra_sum 195.60552600487264 extra_sum 1021.4265254864802 discrimination_value -1.961134145341017

# %%
# compare pre-trained vs not pre-trained

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from evaluate.helper_functions import load_dbn
from evaluate.finetune_dbn import keras_model_from_dbn
from evaluate.feedforward import *
from tensorflow.keras import backend as K

# %%
save_path = os.path.join('mnist_test1', 'finetune/')
if not os.path.exists(save_path):
    os.makedirs(save_path)
    
# load dbn
dbn_path = 'mnist_test1/'
dbn = load_dbn(dbn_path + 'dbn.pickle')

# load data
(x_train, y_train), (x_test, y_test) = load_mnist_data()

# threshold data
x_train = threshold_data(x_train, 0.5 * 255)
x_test = threshold_data(x_test, 0.5 * 255)

# make one hot labels
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# set up model
num_classes = 10
dropout_rates = [0.0, 0.0, 0.0]
optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model = keras_model_from_dbn(dbn, num_classes, dropout_rates, optimizer, use_hbiases=True)
model.summary()

# train model:
batch_size = 128
epochs = 50
history = model.fit(x=x_train[:3000],
                    y=y_train[:3000],
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=(x_test, y_test),
                    verbose=2)

pickle_out = open(save_path + 'finetune_history.pickle', 'wb')
pickle.dump(history.history, pickle_out)
pickle_out.close()

plt.plot(history.history['acc'], label='Train Acc')
plt.plot(history.history['val_acc'], label='Test Acc')
plt.savefig(save_path + 'finettune_acc.png', format='png')
plt.close()
K.clear_session()

# compare with feedforward
finetune_test_acc = history.history['val_acc']

# set up model
num_classes = 10
layer_sizes = [dbn[0].num_vunits]
layer_sizes = layer_sizes + [layer.num_hunits for layer in dbn]
dropout_rates = [0.0, 0.0, 0.0]
optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model = feedforward_network(layer_sizes=layer_sizes,
                            dropout_rates=dropout_rates,
                            num_classes=num_classes,
                            optimizer=optimizer,
                            activation='sigmoid')
model.summary()

# train model:
batch_size = 128
epochs = 50
history = model.fit(x=x_train[:3000],
                    y=y_train[:3000],
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=(x_test, y_test),
                    verbose=2)

pickle_out = open(save_path + 'feedforward_history.pickle', 'wb')
pickle.dump(history.history, pickle_out)
pickle_out.close()

plt.plot(history.history['acc'], label='Train Acc')
plt.plot(history.history['val_acc'], label='Test Acc')
plt.savefig(save_path + 'feedforward_acc.png', format='png')
plt.close()

feedforward_test_acc = history.history['val_acc']

plt.plot(finetune_test_acc)
plt.plot(feedforward_test_acc)
plt.show()
# Out:
# mnist/data already exists, loaded files.
# shape training examples:  (60000, 784)
# shape training labels:  (60000,)
# shape test examples:  (10000, 784)
# shape test labels:  (10000,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 269,322
# Trainable params: 269,322
# Non-trainable params: 0
# _________________________________________________________________
# Train on 3000 samples, validate on 10000 samples
# Epoch 1/50
#  - 0s - loss: 2.1260 - acc: 0.2860 - val_loss: 1.7979 - val_acc: 0.4805
# Epoch 2/50
#  - 0s - loss: 1.4980 - acc: 0.6600 - val_loss: 1.2944 - val_acc: 0.7221
# Epoch 3/50
#  - 0s - loss: 1.0568 - acc: 0.8103 - val_loss: 0.9512 - val_acc: 0.8079
# Epoch 4/50
#  - 0s - loss: 0.7712 - acc: 0.8560 - val_loss: 0.7317 - val_acc: 0.8475
# Epoch 5/50
#  - 0s - loss: 0.5910 - acc: 0.8850 - val_loss: 0.5933 - val_acc: 0.8711
# Epoch 6/50
#  - 0s - loss: 0.4714 - acc: 0.9047 - val_loss: 0.5022 - val_acc: 0.8857
# Epoch 7/50
#  - 0s - loss: 0.3895 - acc: 0.9197 - val_loss: 0.4450 - val_acc: 0.8940
# Epoch 8/50
#  - 0s - loss: 0.3325 - acc: 0.9320 - val_loss: 0.4036 - val_acc: 0.9013
# Epoch 9/50
#  - 0s - loss: 0.2905 - acc: 0.9390 - val_loss: 0.3747 - val_acc: 0.9056
# Epoch 10/50
#  - 0s - loss: 0.2560 - acc: 0.9493 - val_loss: 0.3518 - val_acc: 0.9079
# Epoch 11/50
#  - 0s - loss: 0.2276 - acc: 0.9530 - val_loss: 0.3331 - val_acc: 0.9119
# Epoch 12/50
#  - 0s - loss: 0.2034 - acc: 0.9593 - val_loss: 0.3186 - val_acc: 0.9141
# Epoch 13/50
#  - 0s - loss: 0.1828 - acc: 0.9650 - val_loss: 0.3062 - val_acc: 0.9162
# Epoch 14/50
#  - 0s - loss: 0.1640 - acc: 0.9693 - val_loss: 0.2960 - val_acc: 0.9180
# Epoch 15/50
#  - 0s - loss: 0.1479 - acc: 0.9727 - val_loss: 0.2874 - val_acc: 0.9196
# Epoch 16/50
#  - 0s - loss: 0.1338 - acc: 0.9767 - val_loss: 0.2798 - val_acc: 0.9209
# Epoch 17/50
#  - 0s - loss: 0.1213 - acc: 0.9807 - val_loss: 0.2738 - val_acc: 0.9219
# Epoch 18/50
#  - 0s - loss: 0.1100 - acc: 0.9823 - val_loss: 0.2686 - val_acc: 0.9214
# Epoch 19/50
#  - 0s - loss: 0.0998 - acc: 0.9843 - val_loss: 0.2629 - val_acc: 0.9236
# Epoch 20/50
#  - 0s - loss: 0.0910 - acc: 0.9880 - val_loss: 0.2590 - val_acc: 0.9235
# Epoch 21/50
#  - 0s - loss: 0.0831 - acc: 0.9897 - val_loss: 0.2553 - val_acc: 0.9250
# Epoch 22/50
#  - 0s - loss: 0.0755 - acc: 0.9910 - val_loss: 0.2521 - val_acc: 0.9254
# Epoch 23/50
#  - 0s - loss: 0.0688 - acc: 0.9923 - val_loss: 0.2494 - val_acc: 0.9253
# Epoch 24/50
#  - 0s - loss: 0.0628 - acc: 0.9937 - val_loss: 0.2469 - val_acc: 0.9265
# Epoch 25/50
#  - 0s - loss: 0.0572 - acc: 0.9937 - val_loss: 0.2442 - val_acc: 0.9268
# Epoch 26/50
#  - 0s - loss: 0.0526 - acc: 0.9947 - val_loss: 0.2428 - val_acc: 0.9272
# Epoch 27/50
#  - 0s - loss: 0.0483 - acc: 0.9960 - val_loss: 0.2409 - val_acc: 0.9274
# Epoch 28/50
#  - 0s - loss: 0.0443 - acc: 0.9963 - val_loss: 0.2396 - val_acc: 0.9278
# Epoch 29/50
#  - 0s - loss: 0.0408 - acc: 0.9970 - val_loss: 0.2383 - val_acc: 0.9281
# Epoch 30/50
#  - 0s - loss: 0.0374 - acc: 0.9970 - val_loss: 0.2372 - val_acc: 0.9284
# Epoch 31/50
#  - 0s - loss: 0.0346 - acc: 0.9973 - val_loss: 0.2365 - val_acc: 0.9282
# Epoch 32/50
#  - 0s - loss: 0.0320 - acc: 0.9977 - val_loss: 0.2352 - val_acc: 0.9283
# Epoch 33/50
#  - 0s - loss: 0.0296 - acc: 0.9987 - val_loss: 0.2344 - val_acc: 0.9286
# Epoch 34/50
#  - 0s - loss: 0.0275 - acc: 0.9987 - val_loss: 0.2343 - val_acc: 0.9283
# Epoch 35/50
#  - 0s - loss: 0.0256 - acc: 0.9993 - val_loss: 0.2330 - val_acc: 0.9288
# Epoch 36/50
#  - 0s - loss: 0.0237 - acc: 0.9997 - val_loss: 0.2325 - val_acc: 0.9287
# Epoch 37/50
#  - 0s - loss: 0.0221 - acc: 0.9997 - val_loss: 0.2323 - val_acc: 0.9288
# Epoch 38/50
#  - 0s - loss: 0.0206 - acc: 0.9997 - val_loss: 0.2318 - val_acc: 0.9287
# Epoch 39/50
#  - 0s - loss: 0.0193 - acc: 0.9997 - val_loss: 0.2316 - val_acc: 0.9291
# Epoch 40/50
#  - 0s - loss: 0.0181 - acc: 1.0000 - val_loss: 0.2309 - val_acc: 0.9291
# Epoch 41/50
#  - 0s - loss: 0.0169 - acc: 1.0000 - val_loss: 0.2310 - val_acc: 0.9294
# Epoch 42/50
#  - 0s - loss: 0.0159 - acc: 1.0000 - val_loss: 0.2308 - val_acc: 0.9292
# Epoch 43/50
#  - 0s - loss: 0.0149 - acc: 1.0000 - val_loss: 0.2307 - val_acc: 0.9297
# Epoch 44/50
#  - 0s - loss: 0.0141 - acc: 1.0000 - val_loss: 0.2308 - val_acc: 0.9297
# Epoch 45/50
#  - 0s - loss: 0.0133 - acc: 1.0000 - val_loss: 0.2310 - val_acc: 0.9300
# Epoch 46/50
#  - 0s - loss: 0.0125 - acc: 1.0000 - val_loss: 0.2309 - val_acc: 0.9294
# Epoch 47/50
#  - 0s - loss: 0.0119 - acc: 1.0000 - val_loss: 0.2308 - val_acc: 0.9296
# Epoch 48/50
#  - 0s - loss: 0.0112 - acc: 1.0000 - val_loss: 0.2310 - val_acc: 0.9298
# Epoch 49/50
#  - 0s - loss: 0.0106 - acc: 1.0000 - val_loss: 0.2308 - val_acc: 0.9298
# Epoch 50/50
#  - 0s - loss: 0.0101 - acc: 1.0000 - val_loss: 0.2312 - val_acc: 0.9302
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 269,322
# Trainable params: 269,322
# Non-trainable params: 0
# _________________________________________________________________
# Train on 3000 samples, validate on 10000 samples
# Epoch 1/50
#  - 0s - loss: 2.1336 - acc: 0.2770 - val_loss: 1.8401 - val_acc: 0.6160
# Epoch 2/50
#  - 0s - loss: 1.5177 - acc: 0.7020 - val_loss: 1.2115 - val_acc: 0.7582
# Epoch 3/50
#  - 0s - loss: 0.9716 - acc: 0.7937 - val_loss: 0.8366 - val_acc: 0.8205
# Epoch 4/50
#  - 0s - loss: 0.6917 - acc: 0.8443 - val_loss: 0.6409 - val_acc: 0.8539
# Epoch 5/50
#  - 0s - loss: 0.5329 - acc: 0.8740 - val_loss: 0.5447 - val_acc: 0.8644
# Epoch 6/50
#  - 0s - loss: 0.4380 - acc: 0.8950 - val_loss: 0.4794 - val_acc: 0.8775
# Epoch 7/50
#  - 0s - loss: 0.3776 - acc: 0.9043 - val_loss: 0.4360 - val_acc: 0.8819
# Epoch 8/50
#  - 0s - loss: 0.3316 - acc: 0.9143 - val_loss: 0.4112 - val_acc: 0.8861
# Epoch 9/50
#  - 0s - loss: 0.2965 - acc: 0.9260 - val_loss: 0.3874 - val_acc: 0.8888
# Epoch 10/50
#  - 0s - loss: 0.2677 - acc: 0.9350 - val_loss: 0.3703 - val_acc: 0.8934
# Epoch 11/50
#  - 0s - loss: 0.2454 - acc: 0.9403 - val_loss: 0.3657 - val_acc: 0.8930
# Epoch 12/50
#  - 0s - loss: 0.2244 - acc: 0.9453 - val_loss: 0.3585 - val_acc: 0.8942
# Epoch 13/50
#  - 0s - loss: 0.2074 - acc: 0.9517 - val_loss: 0.3499 - val_acc: 0.8957
# Epoch 14/50
#  - 0s - loss: 0.1920 - acc: 0.9563 - val_loss: 0.3478 - val_acc: 0.8960
# Epoch 15/50
#  - 0s - loss: 0.1791 - acc: 0.9587 - val_loss: 0.3396 - val_acc: 0.8985
# Epoch 16/50
#  - 0s - loss: 0.1660 - acc: 0.9580 - val_loss: 0.3308 - val_acc: 0.9017
# Epoch 17/50
#  - 0s - loss: 0.1551 - acc: 0.9657 - val_loss: 0.3381 - val_acc: 0.8966
# Epoch 18/50
#  - 0s - loss: 0.1403 - acc: 0.9683 - val_loss: 0.3338 - val_acc: 0.8987
# Epoch 19/50
#  - 0s - loss: 0.1313 - acc: 0.9710 - val_loss: 0.3362 - val_acc: 0.8989
# Epoch 20/50
#  - 0s - loss: 0.1224 - acc: 0.9733 - val_loss: 0.3335 - val_acc: 0.8990
# Epoch 21/50
#  - 0s - loss: 0.1120 - acc: 0.9783 - val_loss: 0.3294 - val_acc: 0.8998
# Epoch 22/50
#  - 0s - loss: 0.1042 - acc: 0.9780 - val_loss: 0.3314 - val_acc: 0.9009
# Epoch 23/50
#  - 0s - loss: 0.0958 - acc: 0.9817 - val_loss: 0.3283 - val_acc: 0.9010
# Epoch 24/50
#  - 0s - loss: 0.0896 - acc: 0.9820 - val_loss: 0.3334 - val_acc: 0.8994
# Epoch 25/50
#  - 0s - loss: 0.0843 - acc: 0.9837 - val_loss: 0.3301 - val_acc: 0.9013
# Epoch 26/50
#  - 0s - loss: 0.0772 - acc: 0.9870 - val_loss: 0.3354 - val_acc: 0.9012
# Epoch 27/50
#  - 0s - loss: 0.0706 - acc: 0.9897 - val_loss: 0.3357 - val_acc: 0.9009
# Epoch 28/50
#  - 0s - loss: 0.0648 - acc: 0.9913 - val_loss: 0.3363 - val_acc: 0.9003
# Epoch 29/50
#  - 0s - loss: 0.0600 - acc: 0.9923 - val_loss: 0.3387 - val_acc: 0.9021
# Epoch 30/50
#  - 0s - loss: 0.0557 - acc: 0.9930 - val_loss: 0.3474 - val_acc: 0.8982
# Epoch 31/50
#  - 0s - loss: 0.0511 - acc: 0.9943 - val_loss: 0.3455 - val_acc: 0.8996
# Epoch 32/50
#  - 0s - loss: 0.0477 - acc: 0.9947 - val_loss: 0.3421 - val_acc: 0.9014
# Epoch 33/50
#  - 0s - loss: 0.0426 - acc: 0.9963 - val_loss: 0.3443 - val_acc: 0.9001
# Epoch 34/50
#  - 0s - loss: 0.0405 - acc: 0.9963 - val_loss: 0.3462 - val_acc: 0.9000
# Epoch 35/50
#  - 0s - loss: 0.0380 - acc: 0.9973 - val_loss: 0.3462 - val_acc: 0.9014
# Epoch 36/50
#  - 0s - loss: 0.0347 - acc: 0.9970 - val_loss: 0.3518 - val_acc: 0.8984
# Epoch 37/50
#  - 0s - loss: 0.0320 - acc: 0.9983 - val_loss: 0.3489 - val_acc: 0.9006
# Epoch 38/50
#  - 0s - loss: 0.0297 - acc: 0.9990 - val_loss: 0.3533 - val_acc: 0.9002
# Epoch 39/50
#  - 0s - loss: 0.0271 - acc: 0.9990 - val_loss: 0.3577 - val_acc: 0.8979
# Epoch 40/50
#  - 0s - loss: 0.0247 - acc: 0.9993 - val_loss: 0.3538 - val_acc: 0.9004
# Epoch 41/50
#  - 0s - loss: 0.0230 - acc: 0.9993 - val_loss: 0.3601 - val_acc: 0.9000
# Epoch 42/50
#  - 0s - loss: 0.0222 - acc: 0.9993 - val_loss: 0.3597 - val_acc: 0.9003
# Epoch 43/50
#  - 0s - loss: 0.0197 - acc: 0.9993 - val_loss: 0.3626 - val_acc: 0.9009
# Epoch 44/50
#  - 0s - loss: 0.0190 - acc: 0.9993 - val_loss: 0.3650 - val_acc: 0.9018
# Epoch 45/50
#  - 0s - loss: 0.0171 - acc: 0.9997 - val_loss: 0.3662 - val_acc: 0.9005
# Epoch 46/50
#  - 0s - loss: 0.0161 - acc: 0.9993 - val_loss: 0.3660 - val_acc: 0.9014
# Epoch 47/50
#  - 0s - loss: 0.0148 - acc: 1.0000 - val_loss: 0.3711 - val_acc: 0.8994
# Epoch 48/50
#  - 0s - loss: 0.0142 - acc: 1.0000 - val_loss: 0.3723 - val_acc: 0.9013
# Epoch 49/50
#  - 0s - loss: 0.0132 - acc: 1.0000 - val_loss: 0.3715 - val_acc: 0.9007
# Epoch 50/50
#  - 0s - loss: 0.0124 - acc: 1.0000 - val_loss: 0.3743 - val_acc: 0.9013
