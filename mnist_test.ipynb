# %%
import tensorflow as tf
import numpy as np
import pickle
import os
import matplotlib.pyplot as plt
from evaluate.helper_functions import *

# restrict tensorflow to only one GPU
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
def load_mnist_data():
    """
    Download mnist data if it does not already exist in directory mnist_data, else load it from directory.
    """
    try:
        x_train = np.load('mnist_data/train_data.npy')
        y_train = np.load('mnist_data/train_labels.npy')
        x_test = np.load('mnist_data/test_data.npy')
        y_test = np.load('mnist_data/test_labels.npy')

        print('mnist/data already exists, loaded files.')

    except IOError:
        if not os.path.exists('mnist_data'):
            os.makedirs('mnist_data')
        print('Downloading mnist data.')
        (x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data(path='mnist.npz')

        print('saving mnist data in mnist_data/')
        np.save('mnist_data/train_data', x_train)
        np.save('mnist_data/train_labels', y_train)
        np.save('mnist_data/test_data', x_test)
        np.save('mnist_data/test_labels', y_test)

    # Reshape data into shape [num_samples,num_features]
    x_train = x_train.reshape((x_train.shape[0], -1))
    x_test = x_test.reshape((x_test.shape[0], -1))

    print('shape training examples: ', x_train.shape)
    print('shape training labels: ', y_train.shape)
    print('shape test examples: ', x_test.shape)
    print('shape test labels: ', y_test.shape)

    return (x_train, y_train), (x_test, y_test)


def threshold_data(data, threshold):
    """
    threshold data with threshold value
    :param data: numpy array
    :param threshold: float
    :return: thresholded data
    """
    data = np.where(data >= threshold, np.ones_like(data), np.zeros_like(data))
    data = data.astype(np.float32)
    return data

# %%
# load data
(x_train, y_train), (x_test, y_test) = load_mnist_data()
# Out:
# Downloading mnist data.
# saving mnist data in mnist_data/
# shape training examples:  (60000, 784)
# shape training labels:  (60000,)
# shape test examples:  (10000, 784)
# shape test labels:  (10000,)

# %%
# threshold data
x_train = threshold_data(x_train, 0.5 * 255)
x_test = threshold_data(x_test, 0.5*255)

# %%
# plot one random image to check if the format is correct
plt.imshow(x_train[np.random.randint(x_train.shape[0]), :].reshape([28, 28]), cmap='binary')
plt.colorbar()
plt.show()

# %%
# set up Deep Belief Network
layer_sizes = [784, 256, 256]
layer_types = ['bb', 'bb']
mnist_dbn = generate_dbn(layer_sizes, layer_types)

# %%
# training parameters
dbn_train_params = {
    'epochs': [32, 32],  # number of training epochs
    'batch_size': [128, 128],  # size of one training batch
    'cd_steps': [1, 1],  # number of CD training steps
    'update_vbiases': [True, True],  # if false vbiases are set to zero throughout the training
    'learning_rate': [0.3, 0.3],  # learning rate at the begin of training
    'lr_decay': [(5, 0.5), (5, 0.5)],  # decay of learning rate (every epochs,decay factor)
    'summary_frequency': [250, 250],  # write to summary every x batches
    'sparsity_rate': [0.0, 0.0],  # rate with which sparsity is enforced
    'sparsity_goal': [0.0, 0.0]  # goal activation probability
}

# %%
# Train DBN
summaries_path = 'mnist_test1/'

for li in range(len(mnist_dbn)):
    # set up layer summary path
    summary_path = summaries_path + 'layer{}'.format(li)

    # get training parameters for each layer from DBN_train_params
    layer = mnist_dbn[li]
    epochs = extract_value(dbn_train_params, 'epochs', li, 10)
    batch_size = extract_value(dbn_train_params, 'batch_size', li, 32)
    cd_steps = extract_value(dbn_train_params, 'cd_steps', li, 1)
    update_vbiases = extract_value(dbn_train_params, 'update_vbiases', li, False)
    start_learning_rate = extract_value(dbn_train_params, 'learning_rate', li, 0.1)
    lr_decay = extract_value(dbn_train_params, 'lr_decay', li, (10, 0.9))
    summary_frequency = extract_value(dbn_train_params, 'summary_frequency', li, 10)
    sparsity_rate = extract_value(dbn_train_params, 'sparsity_rate', li, 0)
    sparsity_goal = extract_value(dbn_train_params, 'sparsity_goal', li, 0)

    layer.train_rbm(train_data=x_train,
                    epochs=epochs,
                    batch_size=batch_size,
                    summary_path=summary_path,
                    summary_frequency=summary_frequency,
                    dbn=mnist_dbn,
                    update_vbiases=update_vbiases,
                    start_learning_rate=start_learning_rate,
                    learning_rate_decay=lr_decay,
                    cd_steps=cd_steps,
                    sparsity_rate=sparsity_rate,
                    sparsity_goal=sparsity_goal)

    # save trained dbn:
    pickle_out = open(summaries_path + 'dbn.pickle', 'wb')
    pickle.dump(mnist_dbn, pickle_out)
    pickle_out.close()

    # save parameter dicts:
    pickle_out = open(summaries_path + 'dbn_train_params.pickle', 'wb')
    pickle.dump(dbn_train_params, pickle_out)
    pickle_out.close()
# Out:
# WARNING:tensorflow:From C:\Users\Jonas\Documents\RBM\RBM_project\train\rbm.py:126: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Starting training...
# Epoch 0/32
# Epoch 1/32
# Epoch 2/32
# Epoch 3/32
# Epoch 4/32
# Epoch 5/32
# Epoch 6/32
# Epoch 7/32
# Epoch 8/32
# Epoch 9/32
# Epoch 10/32
# Epoch 11/32
# Epoch 12/32
# Epoch 13/32
# Epoch 14/32
# Epoch 15/32
# Epoch 16/32
# Epoch 17/32
# Epoch 18/32
# Epoch 19/32
# Epoch 20/32
# Epoch 21/32
# Epoch 22/32
# Epoch 23/32
# Epoch 24/32
# Epoch 25/32
# Epoch 26/32
# Epoch 27/32
# Epoch 28/32
# Epoch 29/32
# Epoch 30/32
# Epoch 31/32
# Starting training...
# Epoch 0/32
# Epoch 1/32
# Epoch 2/32
# Epoch 3/32
# Epoch 4/32
# Epoch 5/32
# Epoch 6/32
# Epoch 7/32
# Epoch 8/32
# Epoch 9/32
# Epoch 10/32
# Epoch 11/32
# Epoch 12/32
# Epoch 13/32
# Epoch 14/32
# Epoch 15/32
# Epoch 16/32
# Epoch 17/32
# Epoch 18/32
# Epoch 19/32
# Epoch 20/32
# Epoch 21/32
# Epoch 22/32
# Epoch 23/32
# Epoch 24/32
# Epoch 25/32
# Epoch 26/32
# Epoch 27/32
# Epoch 28/32
# Epoch 29/32
# Epoch 30/32
# Epoch 31/32

# %%
# load DBN
dbn_path = 'mnist_test1/'
dbn_path = os.fspath(os.path.join(dbn_path, 'dbn.pickle'))
dbn = load_dbn(dbn_path)

# %%
# plot features
save_path = 'mnist_test1/features/'
if not os.path.exists(save_path):
    os.makedirs(save_path)
    
for layer_index in range(len(dbn)):
    layer = dbn[layer_index]
    inds = np.random.choice(range(layer.num_hunits), size=16, replace=False)

    # plot features with downward propagation
    receptive_fields = downward_propagate_features(dbn, layer_index, inds,
                                                   num_runs=300,
                                                   num_neurons=10,
                                                   activation_value=1.0)
    fig, axes = plt.subplots(4, 4, figsize=(2.895, 2.895))
    for c, ax in enumerate(axes.flat):
        receptive_field = receptive_fields[c]
        ax.imshow(receptive_field.reshape([28, 28]), cmap='seismic')
        ax.set_xticks([])
        ax.set_yticks([])
    plt.subplots_adjust(wspace=0.05, hspace=0.05)
    if save_path is not None:
        plt.savefig(save_path + 'receptive_fields_layer{}.png'.format(layer_index), format='png')
    plt.show()

# %%
import evaluate.dimensionless_disrcrimination_value as ddv
from evaluate.plot import *

# %%
# plot pca and tsne and calculate discrimination value
save_path = 'mnist_test1/pca_and_tsne/'
if not os.path.exists(save_path):
    os.makedirs(save_path)
    
# make samples indices
np.random.seed(420)
test_indices = make_sample_indices(x_test, 400)

test_samples = x_test[test_indices]
test_labels = y_test[test_indices]

# make pca and tsne of the input layer
pca_samples = calculate_pca(test_samples)
tsne_samples = calculate_tsne(test_samples)

# save plots of pca and tsne of the input layer
pca_plot = plot_pca_or_tsne(pca_samples, test_labels, one_hot_labels=False)
plt.savefig(save_path + 'pca_input_layer.png', format='png')
plt.show()

tsne_plot = plot_pca_or_tsne(tsne_samples, test_labels, one_hot_labels=False)
plt.savefig(save_path + 'tsne_input_layer.png', format='png')
plt.show()

# calculate discrimination value
discrimination_values = []
discrimination_value = ddv.discrimination_value(test_samples,
                                                test_labels,
                                                norm='z')
discrimination_values.append(discrimination_value)

# calculate layerwies activations
layer_activations = layerwise_activations(dbn, test_samples, num_activations=100)

# make and plot pca and tsne for higher layers, calculate discrimination value
for layer_index in range(len(dbn)):
    pca_samples = calculate_pca(layer_activations[layer_index])
    tsne_samples = calculate_tsne(layer_activations[layer_index])

    pca_plot = plot_pca_or_tsne(pca_samples, test_labels, one_hot_labels=False)
    plt.savefig(save_path + 'pca_layer{}.png'.format(layer_index), format='png')
    plt.show()

    tsne_plot = plot_pca_or_tsne(tsne_samples, test_labels, one_hot_labels=False)
    plt.savefig(save_path + 'tsne_layer{}.png'.format(layer_index), format='png')
    plt.show()

    discrimination_value = ddv.discrimination_value(layer_activations[layer_index],
                                                    test_labels,
                                                    norm='z')
    discrimination_values.append(discrimination_value)

plt.plot(discrimination_values)
plt.savefig(save_path + 'discrimination_values.png', format='png')
plt.show()
# Out:
# num zero dimensions:  242
# intra_sum 295.61390048869265 extra_sum 1461.767080509992 discrimination_value -1.2552451464852012
# num zero dimensions:  0
# intra_sum 199.7209539855438 extra_sum 1021.1224346009831 discrimination_value -1.6996964120282776
# num zero dimensions:  0
# intra_sum 195.181922524735 extra_sum 1021.6509233248311 discrimination_value -1.9907259994933817

# %%
# compare pre-trained vs not pre-trained

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from evaluate.helper_functions import load_dbn
from evaluate.finetune_dbn import keras_model_from_dbn
from evaluate.feedforward import *
from tensorflow.keras import backend as K

# %%
save_path = os.path.join('mnist_test1', 'finetune/')
if not os.path.exists(save_path):
    os.makedirs(save_path)
    
# load dbn
dbn_path = 'mnist_test1/'
dbn = load_dbn(dbn_path + 'dbn.pickle')

# load data
(x_train, y_train), (x_test, y_test) = load_mnist_data()

# threshold data
x_train = threshold_data(x_train, 0.5 * 255)
x_test = threshold_data(x_test, 0.5 * 255)

# make one hot labels
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# set up model
num_classes = 10
dropout_rates = [0.0, 0.0, 0.0]
optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model = keras_model_from_dbn(dbn, num_classes, dropout_rates, optimizer, use_hbiases=True)
model.summary()

# train model:
batch_size = 128
epochs = 50
history = model.fit(x=x_train[:3000],
                    y=y_train[:3000],
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=(x_test, y_test),
                    verbose=2)

pickle_out = open(save_path + 'finetune_history.pickle', 'wb')
pickle.dump(history.history, pickle_out)
pickle_out.close()

plt.plot(history.history['acc'], label='Train Acc')
plt.plot(history.history['val_acc'], label='Test Acc')
plt.savefig(save_path + 'finettune_acc.png', format='png')
plt.close()
K.clear_session()

# compare with feedforward
finetune_test_acc = history.history['val_acc']

# set up model
num_classes = 10
layer_sizes = [dbn[0].num_vunits]
layer_sizes = layer_sizes + [layer.num_hunits for layer in dbn]
dropout_rates = [0.0, 0.0, 0.0]
optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model = feedforward_network(layer_sizes=layer_sizes,
                            dropout_rates=dropout_rates,
                            num_classes=num_classes,
                            optimizer=optimizer,
                            activation='sigmoid')
model.summary()

# train model:
batch_size = 128
epochs = 50
history = model.fit(x=x_train[:3000],
                    y=y_train[:3000],
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=(x_test, y_test),
                    verbose=2)

pickle_out = open(save_path + 'feedforward_history.pickle', 'wb')
pickle.dump(history.history, pickle_out)
pickle_out.close()

plt.plot(history.history['acc'], label='Train Acc')
plt.plot(history.history['val_acc'], label='Test Acc')
plt.savefig(save_path + 'feedforward_acc.png', format='png')
plt.close()

feedforward_test_acc = history.history['val_acc']

plt.plot(finetune_test_acc)
plt.plot(feedforward_test_acc)
plt.show()
# Out:
# mnist/data already exists, loaded files.
# shape training examples:  (60000, 784)
# shape training labels:  (60000,)
# shape test examples:  (10000, 784)
# shape test labels:  (10000,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 269,322
# Trainable params: 269,322
# Non-trainable params: 0
# _________________________________________________________________
# Train on 3000 samples, validate on 10000 samples
# Epoch 1/50
#  - 1s - loss: 2.1250 - acc: 0.2353 - val_loss: 1.7882 - val_acc: 0.4817
# Epoch 2/50
#  - 0s - loss: 1.5162 - acc: 0.6423 - val_loss: 1.2976 - val_acc: 0.7202
# Epoch 3/50
#  - 0s - loss: 1.0692 - acc: 0.7960 - val_loss: 0.9409 - val_acc: 0.8116
# Epoch 4/50
#  - 0s - loss: 0.7647 - acc: 0.8593 - val_loss: 0.7107 - val_acc: 0.8536
# Epoch 5/50
#  - 0s - loss: 0.5776 - acc: 0.8890 - val_loss: 0.5763 - val_acc: 0.8755
# Epoch 6/50
#  - 0s - loss: 0.4599 - acc: 0.9077 - val_loss: 0.4930 - val_acc: 0.8883
# Epoch 7/50
#  - 0s - loss: 0.3813 - acc: 0.9257 - val_loss: 0.4389 - val_acc: 0.8949
# Epoch 8/50
#  - 0s - loss: 0.3256 - acc: 0.9343 - val_loss: 0.3977 - val_acc: 0.9020
# Epoch 9/50
#  - 0s - loss: 0.2827 - acc: 0.9427 - val_loss: 0.3676 - val_acc: 0.9068
# Epoch 10/50
#  - 0s - loss: 0.2484 - acc: 0.9517 - val_loss: 0.3454 - val_acc: 0.9100
# Epoch 11/50
#  - 0s - loss: 0.2199 - acc: 0.9580 - val_loss: 0.3279 - val_acc: 0.9137
# Epoch 12/50
#  - 0s - loss: 0.1965 - acc: 0.9627 - val_loss: 0.3142 - val_acc: 0.9154
# Epoch 13/50
#  - 0s - loss: 0.1764 - acc: 0.9660 - val_loss: 0.3024 - val_acc: 0.9173
# Epoch 14/50
#  - 0s - loss: 0.1585 - acc: 0.9717 - val_loss: 0.2921 - val_acc: 0.9190
# Epoch 15/50
#  - 0s - loss: 0.1429 - acc: 0.9743 - val_loss: 0.2843 - val_acc: 0.9197
# Epoch 16/50
#  - 0s - loss: 0.1298 - acc: 0.9797 - val_loss: 0.2765 - val_acc: 0.9217
# Epoch 17/50
#  - 0s - loss: 0.1178 - acc: 0.9833 - val_loss: 0.2715 - val_acc: 0.9221
# Epoch 18/50
#  - 0s - loss: 0.1074 - acc: 0.9853 - val_loss: 0.2667 - val_acc: 0.9230
# Epoch 19/50
#  - 0s - loss: 0.0977 - acc: 0.9867 - val_loss: 0.2608 - val_acc: 0.9244
# Epoch 20/50
#  - 0s - loss: 0.0892 - acc: 0.9880 - val_loss: 0.2572 - val_acc: 0.9247
# Epoch 21/50
#  - 0s - loss: 0.0820 - acc: 0.9893 - val_loss: 0.2542 - val_acc: 0.9251
# Epoch 22/50
#  - 0s - loss: 0.0749 - acc: 0.9910 - val_loss: 0.2508 - val_acc: 0.9260
# Epoch 23/50
#  - 0s - loss: 0.0683 - acc: 0.9923 - val_loss: 0.2486 - val_acc: 0.9251
# Epoch 24/50
#  - 0s - loss: 0.0627 - acc: 0.9930 - val_loss: 0.2454 - val_acc: 0.9266
# Epoch 25/50
#  - 0s - loss: 0.0573 - acc: 0.9947 - val_loss: 0.2435 - val_acc: 0.9265
# Epoch 26/50
#  - 0s - loss: 0.0529 - acc: 0.9950 - val_loss: 0.2416 - val_acc: 0.9268
# Epoch 27/50
#  - 0s - loss: 0.0487 - acc: 0.9953 - val_loss: 0.2399 - val_acc: 0.9272
# Epoch 28/50
#  - 0s - loss: 0.0448 - acc: 0.9957 - val_loss: 0.2389 - val_acc: 0.9271
# Epoch 29/50
#  - 0s - loss: 0.0413 - acc: 0.9957 - val_loss: 0.2374 - val_acc: 0.9273
# Epoch 30/50
#  - 0s - loss: 0.0380 - acc: 0.9963 - val_loss: 0.2364 - val_acc: 0.9273
# Epoch 31/50
#  - 0s - loss: 0.0352 - acc: 0.9967 - val_loss: 0.2357 - val_acc: 0.9276
# Epoch 32/50
#  - 0s - loss: 0.0326 - acc: 0.9977 - val_loss: 0.2345 - val_acc: 0.9281
# Epoch 33/50
#  - 0s - loss: 0.0303 - acc: 0.9983 - val_loss: 0.2336 - val_acc: 0.9278
# Epoch 34/50
#  - 0s - loss: 0.0281 - acc: 0.9983 - val_loss: 0.2332 - val_acc: 0.9283
# Epoch 35/50
#  - 0s - loss: 0.0262 - acc: 0.9983 - val_loss: 0.2324 - val_acc: 0.9282
# Epoch 36/50
#  - 0s - loss: 0.0243 - acc: 0.9987 - val_loss: 0.2317 - val_acc: 0.9283
# Epoch 37/50
#  - 0s - loss: 0.0227 - acc: 0.9987 - val_loss: 0.2318 - val_acc: 0.9289
# Epoch 38/50
#  - 0s - loss: 0.0212 - acc: 0.9990 - val_loss: 0.2314 - val_acc: 0.9286
# Epoch 39/50
#  - 0s - loss: 0.0198 - acc: 0.9993 - val_loss: 0.2311 - val_acc: 0.9287
# Epoch 40/50
#  - 0s - loss: 0.0186 - acc: 0.9997 - val_loss: 0.2308 - val_acc: 0.9288
# Epoch 41/50
#  - 0s - loss: 0.0174 - acc: 0.9997 - val_loss: 0.2308 - val_acc: 0.9289
# Epoch 42/50
#  - 0s - loss: 0.0164 - acc: 0.9997 - val_loss: 0.2308 - val_acc: 0.9288
# Epoch 43/50
#  - 0s - loss: 0.0153 - acc: 0.9997 - val_loss: 0.2306 - val_acc: 0.9283
# Epoch 44/50
#  - 0s - loss: 0.0145 - acc: 1.0000 - val_loss: 0.2308 - val_acc: 0.9287
# Epoch 45/50
#  - 0s - loss: 0.0136 - acc: 1.0000 - val_loss: 0.2310 - val_acc: 0.9283
# Epoch 46/50
#  - 0s - loss: 0.0129 - acc: 1.0000 - val_loss: 0.2310 - val_acc: 0.9287
# Epoch 47/50
#  - 0s - loss: 0.0122 - acc: 1.0000 - val_loss: 0.2312 - val_acc: 0.9290
# Epoch 48/50
#  - 0s - loss: 0.0115 - acc: 1.0000 - val_loss: 0.2310 - val_acc: 0.9292
# Epoch 49/50
#  - 0s - loss: 0.0109 - acc: 1.0000 - val_loss: 0.2309 - val_acc: 0.9293
# Epoch 50/50
#  - 0s - loss: 0.0103 - acc: 1.0000 - val_loss: 0.2312 - val_acc: 0.9294
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 784)               201488
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               200960
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 605,978
# Trainable params: 605,978
# Non-trainable params: 0
# _________________________________________________________________
# Train on 3000 samples, validate on 10000 samples
# Epoch 1/50
#  - 2s - loss: 2.3160 - acc: 0.1623 - val_loss: 2.1767 - val_acc: 0.2676
# Epoch 2/50
#  - 1s - loss: 1.9060 - acc: 0.4633 - val_loss: 1.4620 - val_acc: 0.6314
# Epoch 3/50
#  - 1s - loss: 1.1059 - acc: 0.6987 - val_loss: 0.8959 - val_acc: 0.7094
# Epoch 4/50
#  - 1s - loss: 0.7344 - acc: 0.7807 - val_loss: 0.6787 - val_acc: 0.8059
# Epoch 5/50
#  - 1s - loss: 0.5477 - acc: 0.8450 - val_loss: 0.5637 - val_acc: 0.8282
# Epoch 6/50
#  - 1s - loss: 0.4420 - acc: 0.8770 - val_loss: 0.5125 - val_acc: 0.8466
# Epoch 7/50
#  - 1s - loss: 0.3851 - acc: 0.8857 - val_loss: 0.4341 - val_acc: 0.8716
# Epoch 8/50
#  - 1s - loss: 0.3211 - acc: 0.9110 - val_loss: 0.4252 - val_acc: 0.8685
# Epoch 9/50
#  - 1s - loss: 0.2888 - acc: 0.9217 - val_loss: 0.4111 - val_acc: 0.8734
# Epoch 10/50
#  - 1s - loss: 0.2570 - acc: 0.9313 - val_loss: 0.3821 - val_acc: 0.8834
# Epoch 11/50
#  - 1s - loss: 0.2346 - acc: 0.9390 - val_loss: 0.3666 - val_acc: 0.8863
# Epoch 12/50
#  - 1s - loss: 0.2140 - acc: 0.9427 - val_loss: 0.3650 - val_acc: 0.8896
# Epoch 13/50
#  - 1s - loss: 0.1884 - acc: 0.9530 - val_loss: 0.3528 - val_acc: 0.8913
# Epoch 14/50
#  - 1s - loss: 0.1763 - acc: 0.9540 - val_loss: 0.3723 - val_acc: 0.8872
# Epoch 15/50
#  - 1s - loss: 0.1625 - acc: 0.9580 - val_loss: 0.3449 - val_acc: 0.8954
# Epoch 16/50
#  - 1s - loss: 0.1452 - acc: 0.9633 - val_loss: 0.3478 - val_acc: 0.8958
# Epoch 17/50
#  - 1s - loss: 0.1352 - acc: 0.9673 - val_loss: 0.3492 - val_acc: 0.8956
# Epoch 18/50
#  - 1s - loss: 0.1170 - acc: 0.9733 - val_loss: 0.3531 - val_acc: 0.8949
# Epoch 19/50
#  - 1s - loss: 0.1094 - acc: 0.9747 - val_loss: 0.3483 - val_acc: 0.8991
# Epoch 20/50
#  - 1s - loss: 0.0973 - acc: 0.9797 - val_loss: 0.3570 - val_acc: 0.8945
# Epoch 21/50
#  - 1s - loss: 0.0856 - acc: 0.9857 - val_loss: 0.3477 - val_acc: 0.8993
# Epoch 22/50
#  - 1s - loss: 0.0797 - acc: 0.9837 - val_loss: 0.3601 - val_acc: 0.8959
# Epoch 23/50
#  - 1s - loss: 0.0711 - acc: 0.9883 - val_loss: 0.3501 - val_acc: 0.8988
# Epoch 24/50
#  - 1s - loss: 0.0639 - acc: 0.9907 - val_loss: 0.3669 - val_acc: 0.8916
# Epoch 25/50
#  - 1s - loss: 0.0603 - acc: 0.9907 - val_loss: 0.3584 - val_acc: 0.8976
# Epoch 26/50
#  - 1s - loss: 0.0516 - acc: 0.9920 - val_loss: 0.3573 - val_acc: 0.8993
# Epoch 27/50
#  - 1s - loss: 0.0461 - acc: 0.9933 - val_loss: 0.3644 - val_acc: 0.8966
# Epoch 28/50
#  - 1s - loss: 0.0392 - acc: 0.9960 - val_loss: 0.3643 - val_acc: 0.8961
# Epoch 29/50
#  - 1s - loss: 0.0363 - acc: 0.9960 - val_loss: 0.3668 - val_acc: 0.8979
# Epoch 30/50
#  - 1s - loss: 0.0318 - acc: 0.9970 - val_loss: 0.3727 - val_acc: 0.8972
# Epoch 31/50
#  - 1s - loss: 0.0287 - acc: 0.9977 - val_loss: 0.3768 - val_acc: 0.8968
# Epoch 32/50
#  - 1s - loss: 0.0257 - acc: 0.9983 - val_loss: 0.3720 - val_acc: 0.8978
# Epoch 33/50
#  - 1s - loss: 0.0235 - acc: 0.9990 - val_loss: 0.3761 - val_acc: 0.8972
# Epoch 34/50
#  - 1s - loss: 0.0205 - acc: 0.9987 - val_loss: 0.3755 - val_acc: 0.8982
# Epoch 35/50
#  - 1s - loss: 0.0186 - acc: 0.9990 - val_loss: 0.3775 - val_acc: 0.8979
# Epoch 36/50
#  - 1s - loss: 0.0172 - acc: 0.9990 - val_loss: 0.3815 - val_acc: 0.8979
# Epoch 37/50
#  - 1s - loss: 0.0154 - acc: 0.9990 - val_loss: 0.3807 - val_acc: 0.8980
# Epoch 38/50
#  - 1s - loss: 0.0139 - acc: 0.9990 - val_loss: 0.3837 - val_acc: 0.8996
# Epoch 39/50
#  - 1s - loss: 0.0122 - acc: 0.9997 - val_loss: 0.3896 - val_acc: 0.8974
# Epoch 40/50
#  - 1s - loss: 0.0111 - acc: 0.9997 - val_loss: 0.3874 - val_acc: 0.8992
# Epoch 41/50
#  - 1s - loss: 0.0099 - acc: 0.9997 - val_loss: 0.3914 - val_acc: 0.8985
# Epoch 42/50
#  - 1s - loss: 0.0095 - acc: 1.0000 - val_loss: 0.3933 - val_acc: 0.8984
# Epoch 43/50
#  - 1s - loss: 0.0082 - acc: 1.0000 - val_loss: 0.3952 - val_acc: 0.8986
# Epoch 44/50
#  - 1s - loss: 0.0079 - acc: 1.0000 - val_loss: 0.3989 - val_acc: 0.8986
# Epoch 45/50
#  - 1s - loss: 0.0071 - acc: 1.0000 - val_loss: 0.3987 - val_acc: 0.8995
# Epoch 46/50
#  - 1s - loss: 0.0067 - acc: 1.0000 - val_loss: 0.3988 - val_acc: 0.8995
# Epoch 47/50
#  - 1s - loss: 0.0061 - acc: 1.0000 - val_loss: 0.4051 - val_acc: 0.8984
# Epoch 48/50
#  - 1s - loss: 0.0059 - acc: 1.0000 - val_loss: 0.4075 - val_acc: 0.8980
# Epoch 49/50
#  - 1s - loss: 0.0055 - acc: 1.0000 - val_loss: 0.4033 - val_acc: 0.8998
# Epoch 50/50
#  - 1s - loss: 0.0051 - acc: 1.0000 - val_loss: 0.4060 - val_acc: 0.8995
